# %% [markdown]
# # Chair free pandas dataframe

# %%
import pandas as pd
import numpy as np
pd.set_option("display.precision", 3)

header = ['timestamp','AX','AY','AZ','GX','GY','GZ','MX','MY','MZ','Roll','Pitch','Yaw','Q1','Q2','Q3','Q4']

dataset_free = pd.read_csv('chairFree3.csv',skiprows=1,delimiter=';')

# %%
dataset.head(100)
# Out:
#     timestamp     AX     AY     AZ     GX     GY     GZ   MX      MY    MZ  \
# 0   1.549e+09  0.973  0.513  9.440  0.052  0.011  0.017  6.0  16.199  58.8
# 1   1.549e+09 -1.012  0.441  9.386  0.054  0.012  0.019  6.0  16.199  58.8
# 2   1.549e+09 -1.007  0.453  9.434  0.053  0.012  0.020  6.3  13.500  57.9
# 3   1.549e+09  0.979  0.521  9.407  0.054  0.013  0.020  6.3  13.500  57.9
# 4   1.549e+09 -1.025  0.509  9.397  0.055  0.014  0.019  6.3  13.500  57.9
# 5   1.549e+09 -1.000  0.454  9.424  0.055  0.015  0.020  6.3  13.500  57.9
# 6   1.549e+09  0.944  0.465  9.460  0.054  0.014  0.020  6.3  13.500  57.9
# 7   1.549e+09  0.984  0.502  9.392  0.053  0.014  0.020  4.5  14.700  57.9
# 8   1.549e+09  0.945  0.495  9.455  0.053  0.012  0.019  4.5  14.700  57.9
# 9   1.549e+09  0.980  0.453  9.448  0.052  0.012  0.017  4.5  14.700  57.9
# 10  1.549e+09  0.993  0.447  9.447  0.052  0.012  0.017  4.5  14.700  57.9
# ...

# %%
dataset_free.describe()
# Out:
#        timestamp         AX         AY         AZ         GX         GY  \
# count  8.276e+04  82764.000  82764.000  82764.000  82764.000  8.276e+04
# mean   1.549e+09      0.902      0.490      9.436      0.052  1.189e-02
# std    4.781e+02      0.207      0.025      0.032      0.001  9.287e-04
# min    1.549e+09     -1.441     -1.150      8.376      0.000  0.000e+00
# 25%    1.549e+09      0.906      0.478      9.415      0.051  1.100e-02
# 50%    1.549e+09      0.924      0.490      9.435      0.052  1.200e-02
# 75%    1.549e+09      0.940      0.503      9.457      0.052  1.200e-02
# max    1.549e+09      0.999      0.999     10.429      0.090  5.800e-02
#
#               GZ         MX         MY         MZ       Roll      Pitch  \
# count  82764.000  82764.000  82764.000  82764.000  82764.000  82764.000
# mean       0.006      4.214     14.014     57.967     -3.098      5.520
# std        0.012      0.947      0.812      0.825      0.078      0.096
# ...

# %% [markdown]
# # Chair in-use pandas dataframe

# %%
import pandas as pd
import numpy as np
import time

pd.set_option("display.precision", 3)

#header ['timestamp','AX','AY','AZ','GX','GY','GZ','MX','MY','MZ','Roll','Pitch','Yaw','Q1','Q2','Q3','Q4']

dataset_inuse = pd.read_csv('chairInUse3.csv',delimiter=';',skiprows=1)


#Fix wrong label

dataset_inuse['LABEL']="IN_USE"

# %%
dataset_inuse.head(100)
# Out:
#     timestamp     AX     AY     AZ     GX     GY     GZ   MX      MY      MZ  \
# 0   1.549e+09  0.969  0.531  9.615  0.068  0.027  0.017  1.2  15.000  54.000
# 1   1.549e+09  0.974  0.586  9.459  0.072  0.023  0.010  1.2  15.000  54.000
# 2   1.549e+09  0.927  0.587  9.451  0.073  0.019  0.001  1.2  15.000  54.000
# 3   1.549e+09  0.921  0.588  9.490  0.072  0.019  0.010  1.2  15.000  54.000
# 4   1.549e+09  0.943  0.530  9.451  0.071  0.017  0.013  1.2  14.400  55.199
# 5   1.549e+09  0.932  0.531  9.490  0.072  0.016  0.015  1.2  14.400  55.199
# 6   1.549e+09  0.958  0.636  9.483  0.075  0.015  0.022  1.2  14.400  55.199
# 7   1.549e+09  0.920  0.648  9.500  0.077  0.017  0.031  1.2  14.400  55.199
# 8   1.549e+09  0.913  0.605  9.518  0.074  0.017  0.042  1.2  14.400  55.199
# 9   1.549e+09  0.991  0.622  9.430  0.072  0.017  0.051  2.4  13.799  54.600
# 10  1.549e+09  0.984  0.569  9.497  0.071  0.020  0.058  2.4  13.799  54.600
# ...

# %%
dataset_inuse.describe()
# Out:
#        timestamp          AX          AY          AZ          GX          GY  \
# count  1.766e+05  176564.000  176564.000  176564.000  176564.000  176564.000
# mean   1.549e+09       0.670       0.509       9.459       0.054       0.011
# std    1.022e+03       0.589       0.064       0.041       0.005       0.005
# min    1.549e+09      -2.019      -1.884       7.212       0.000       0.000
# 25%    1.549e+09       0.822       0.487       9.434       0.053       0.010
# 50%    1.549e+09       0.855       0.514       9.458       0.054       0.011
# 75%    1.549e+09       0.887       0.538       9.482       0.055       0.012
# max    1.549e+09       0.999       1.121      10.512       0.155       0.226
#
#                GZ          MX          MY          MZ        Roll       Pitch  \
# count  176564.000  176564.000  176564.000  176564.000  176564.000  176564.000
# mean        0.011       1.132      12.785      54.284      -3.196       5.287
# ...

# %%
print(dataset_inuse.shape)
print(dataset_free.shape)
# Out:
# (176564, 18)
# (82764, 18)

# %%
from pandas import Series
from matplotlib import pyplot
series = dataset_free['AX']
series.plot()
pyplot.show()
